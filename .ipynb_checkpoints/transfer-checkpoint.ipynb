# %%
import pandas, cv2, json, os

# %%
annotation = pandas.read_csv("/home/dsd/Desktop/calendar_faster_rcnn/dataset/calendar.csv")
annotation
# Out:
#     filename  file_size                                    file_attributes  \
# 0      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 1      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 2      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 3      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 4      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 5      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 6      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 7      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 8      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 9      1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 10     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 11     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 12     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 13     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 14     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 15     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 16     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 17     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 18     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 19     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 20     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 21     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 22     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 23     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 24     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 25     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 26     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 27     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 28     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# 29     1.jpg     181449  {"caption":"","public_domain":"no","image_url"...
# ..       ...        ...                                                ...
# 155    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 156    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 157    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 158    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 159    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 160    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 161    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 162    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 163    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 164    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 165    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 166    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 167    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 168    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 169    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 170    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 171    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 172    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 173    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 174    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 175    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 176    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 177    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 178    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 179    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 180    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 181    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 182    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 183    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
# 184    6.jpg      33835  {"caption":"","public_domain":"no","image_url"...
#
#      region_count  region_id  \
# 0              31          0
# 1              31          1
# 2              31          2
# 3              31          3
# 4              31          4
# 5              31          5
# 6              31          6
# 7              31          7
# 8              31          8
# 9              31          9
# 10             31         10
# 11             31         11
# 12             31         12
# 13             31         13
# 14             31         14
# 15             31         15
# 16             31         16
# 17             31         17
# 18             31         18
# 19             31         19
# 20             31         20
# 21             31         21
# 22             31         22
# 23             31         23
# 24             31         24
# 25             31         25
# 26             31         26
# 27             31         27
# 28             31         28
# 29             31         29
# ..            ...        ...
# 155            31          1
# 156            31          2
# 157            31          3
# 158            31          4
# 159            31          5
# 160            31          6
# 161            31          7
# 162            31          8
# 163            31          9
# 164            31         10
# 165            31         11
# 166            31         12
# 167            31         13
# 168            31         14
# 169            31         15
# 170            31         16
# 171            31         17
# 172            31         18
# 173            31         19
# 174            31         20
# 175            31         21
# 176            31         22
# 177            31         23
# 178            31         24
# 179            31         25
# 180            31         26
# 181            31         27
# 182            31         28
# 183            31         29
# 184            31         30
#
#                                region_shape_attributes  \
# 0    {"name":"rect","x":42,"y":122,"width":12,"heig...
# 1    {"name":"rect","x":127,"y":121,"width":14,"hei...
# 2    {"name":"rect","x":214,"y":122,"width":14,"hei...
# 3    {"name":"rect","x":302,"y":122,"width":13,"hei...
# 4    {"name":"rect","x":389,"y":121,"width":13,"hei...
# 5    {"name":"rect","x":476,"y":120,"width":15,"hei...
# 6    {"name":"rect","x":564,"y":119,"width":13,"hei...
# 7    {"name":"rect","x":41,"y":188,"width":15,"heig...
# 8    {"name":"rect","x":127,"y":188,"width":15,"hei...
# 9    {"name":"rect","x":212,"y":188,"width":21,"hei...
# 10   {"name":"rect","x":298,"y":188,"width":22,"hei...
# 11   {"name":"rect","x":385,"y":187,"width":23,"hei...
# 12   {"name":"rect","x":473,"y":188,"width":22,"hei...
# 13   {"name":"rect","x":560,"y":187,"width":23,"hei...
# 14   {"name":"rect","x":38,"y":254,"width":22,"heig...
# 15   {"name":"rect","x":124,"y":254,"width":22,"hei...
# 16   {"name":"rect","x":212,"y":254,"width":21,"hei...
# 17   {"name":"rect","x":298,"y":255,"width":23,"hei...
# 18   {"name":"rect","x":385,"y":254,"width":22,"hei...
# 19   {"name":"rect","x":471,"y":255,"width":23,"hei...
# 20   {"name":"rect","x":558,"y":254,"width":22,"hei...
# 21   {"name":"rect","x":37,"y":322,"width":23,"heig...
# 22   {"name":"rect","x":123,"y":322,"width":22,"hei...
# 23   {"name":"rect","x":210,"y":322,"width":21,"hei...
# 24   {"name":"rect","x":297,"y":322,"width":23,"hei...
# 25   {"name":"rect","x":384,"y":322,"width":22,"hei...
# 26   {"name":"rect","x":472,"y":321,"width":22,"hei...
# 27   {"name":"rect","x":559,"y":322,"width":24,"hei...
# 28   {"name":"rect","x":37,"y":389,"width":23,"heig...
# 29   {"name":"rect","x":123,"y":389,"width":22,"hei...
# ..                                                 ...
# 155  {"name":"rect","x":122,"y":68,"width":18,"heig...
# 156  {"name":"rect","x":197,"y":69,"width":15,"heig...
# 157  {"name":"rect","x":268,"y":67,"width":17,"heig...
# 158  {"name":"rect","x":342,"y":68,"width":16,"heig...
# 159  {"name":"rect","x":414,"y":67,"width":16,"heig...
# 160  {"name":"rect","x":486,"y":68,"width":15,"heig...
# 161  {"name":"rect","x":51,"y":132,"width":17,"heig...
# 162  {"name":"rect","x":123,"y":131,"width":18,"hei...
# 163  {"name":"rect","x":185,"y":131,"width":28,"hei...
# 164  {"name":"rect","x":256,"y":131,"width":27,"hei...
# 165  {"name":"rect","x":330,"y":130,"width":27,"hei...
# 166  {"name":"rect","x":402,"y":131,"width":28,"hei...
# 167  {"name":"rect","x":475,"y":130,"width":28,"hei...
# 168  {"name":"rect","x":40,"y":193,"width":28,"heig...
# 169  {"name":"rect","x":112,"y":194,"width":27,"hei...
# 170  {"name":"rect","x":185,"y":194,"width":26,"hei...
# 171  {"name":"rect","x":257,"y":194,"width":27,"hei...
# 172  {"name":"rect","x":330,"y":193,"width":27,"hei...
# 173  {"name":"rect","x":399,"y":193,"width":30,"hei...
# 174  {"name":"rect","x":473,"y":193,"width":27,"hei...
# 175  {"name":"rect","x":39,"y":256,"width":29,"heig...
# 176  {"name":"rect","x":110,"y":257,"width":29,"hei...
# 177  {"name":"rect","x":184,"y":256,"width":29,"hei...
# 178  {"name":"rect","x":256,"y":256,"width":28,"hei...
# 179  {"name":"rect","x":329,"y":256,"width":28,"hei...
# 180  {"name":"rect","x":400,"y":256,"width":29,"hei...
# 181  {"name":"rect","x":474,"y":256,"width":29,"hei...
# 182  {"name":"rect","x":38,"y":319,"width":28,"heig...
# 183  {"name":"rect","x":111,"y":320,"width":28,"hei...
# 184  {"name":"rect","x":183,"y":319,"width":28,"hei...
#
#                                      region_attributes
# 0    {"name":"date","type":"1","image_quality":{"go...
# 1    {"name":"date","type":"2","image_quality":{"go...
# 2    {"name":"date","type":"3","image_quality":{"go...
# 3    {"name":"date","type":"4","image_quality":{"go...
# 4    {"name":"date","type":"5","image_quality":{"go...
# 5    {"name":"date","type":"6","image_quality":{"go...
# 6    {"name":"date","type":"7","image_quality":{"go...
# 7    {"name":"date","type":"8","image_quality":{"go...
# 8    {"name":"date","type":"9","image_quality":{"go...
# 9    {"name":"date","type":"10","image_quality":{"g...
# 10   {"name":"date","type":"11","image_quality":{"g...
# 11   {"name":"date","type":"12","image_quality":{"g...
# 12   {"name":"date","type":"13","image_quality":{"g...
# 13   {"name":"date","type":"14","image_quality":{"g...
# 14   {"name":"date","type":"15","image_quality":{"g...
# 15   {"name":"date","type":"16","image_quality":{"g...
# 16   {"name":"date","type":"17","image_quality":{"g...
# 17   {"name":"date","type":"18","image_quality":{"g...
# 18   {"name":"date","type":"19","image_quality":{"g...
# 19   {"name":"date","type":"20","image_quality":{"g...
# 20   {"name":"date","type":"21","image_quality":{"g...
# 21   {"name":"date","type":"22","image_quality":{"g...
# 22   {"name":"date","type":"23","image_quality":{"g...
# 23   {"name":"date","type":"24","image_quality":{"g...
# 24   {"name":"date","type":"25","image_quality":{"g...
# 25   {"name":"date","type":"26","image_quality":{"g...
# 26   {"name":"date","type":"27","image_quality":{"g...
# 27   {"name":"date","type":"28","image_quality":{"g...
# 28   {"name":"date","type":"29","image_quality":{"g...
# 29   {"name":"date","type":"30","image_quality":{"g...
# ..                                                 ...
# 155  {"name":"date","type":"2","image_quality":{"go...
# 156  {"name":"date","type":"3","image_quality":{"go...
# 157  {"name":"date","type":"4","image_quality":{"go...
# 158  {"name":"date","type":"5","image_quality":{"go...
# 159  {"name":"date","type":"6","image_quality":{"go...
# 160  {"name":"date","type":"7","image_quality":{"go...
# 161  {"name":"date","type":"8","image_quality":{"go...
# 162  {"name":"date","type":"9","image_quality":{"go...
# 163  {"name":"date","type":"10","image_quality":{"g...
# 164  {"name":"date","type":"11","image_quality":{"g...
# 165  {"name":"date","type":"12","image_quality":{"g...
# 166  {"name":"date","type":"13","image_quality":{"g...
# 167  {"name":"date","type":"14","image_quality":{"g...
# 168  {"name":"date","type":"15","image_quality":{"g...
# 169  {"name":"date","type":"16","image_quality":{"g...
# 170  {"name":"date","type":"17","image_quality":{"g...
# 171  {"name":"date","type":"18","image_quality":{"g...
# 172  {"name":"date","type":"19","image_quality":{"g...
# 173  {"name":"date","type":"20","image_quality":{"g...
# 174  {"name":"date","type":"21","image_quality":{"g...
# 175  {"name":"date","type":"22","image_quality":{"g...
# 176  {"name":"date","type":"23","image_quality":{"g...
# 177  {"name":"date","type":"24","image_quality":{"g...
# 178  {"name":"date","type":"25","image_quality":{"g...
# 179  {"name":"date","type":"26","image_quality":{"g...
# 180  {"name":"date","type":"27","image_quality":{"g...
# 181  {"name":"date","type":"28","image_quality":{"g...
# 182  {"name":"date","type":"29","image_quality":{"g...
# 183  {"name":"date","type":"30","image_quality":{"g...
# 184  {"name":"date","type":"31","image_quality":{"g...
#
# [185 rows x 7 columns]

# %%
path = '/home/dsd/Desktop/calendar_faster_rcnn/dataset/train/'
filename = annotation['filename']
coordinate = annotation['region_shape_attributes']
region_id = annotation['region_attributes']
# print(coordinate)
combine = zip(coordinate, region_id)

data = ''
for i, c in enumerate(combine):
#     print(i, c[0], c[1])
    full_filename = path + filename[i]
    m, n = json.loads(c[0]), json.loads(c[1])['type']
#     print(m, n)
    x1, y1, x2, y2 = m['x'], m['y'], m['x'] + m['width'], m['y'] + m['height']
    data += full_filename + ',' + str(x1) + ',' + str(y1) + ',' + str(x2) + ',' + str(y2) + ',' + str(n) + '\n'
    
with open(path + 'annotation.txt', 'w') as f:
    f.write(data)

# %%
import cv2
"""
坐标 x1, y1, x2, y2
opencv裁剪图片: img[y1:y2, x1:y1] 坐标系可能是相反的"""

img = cv2.imread('/home/dsd/Desktop/calendar_faster_rcnn/dataset/train/1.jpg')
cv2.imshow('img', img[122:139, 42:54])
cv2.waitKey(0)
# Out:
# -1
